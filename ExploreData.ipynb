# %% [markdown]
# #Explore the Forest

# %% [markdown]
# Welcome to a forest in Provence, France. In these IPython notebooks you'll explore classifying the birds around you from audio clips of their songs and calls. The code is available [on Github](https://github.com/mattwescott/birds_scipy2014)

# %% [markdown]
# *The data used in this activity were provided during the NIPS4B
# workshop in Nevada 2013, in the Bird challenge, organized by Bas,
# Dufour and Glotin. They shall not be used for another purpose.
# Publication or report using them shall cite:*
#
# *Bas Y., Dufour O., Glotin H., (2013) 'NIP4B Bird Challenge Overview',
# in Proc. of 'Neural Information Processing Scaled for Bioacoustics:
# from Neurons to Big Data- NIP4B', Ed. Glotin et al., joint to NIPS
# Conf., ISSN 979-10-90821-04-0, http://sabiod.org*

# %%
import pandas as pd
import numpy as np

import bird_data as data

import wav_utils

from IPython.core.display import HTML

# Plot in the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /media/extra/kaggle/bird-recognition/venv/local/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %% [markdown]
# ## Explore the data

# %% [markdown]
# ### Which calls will we try to identify?
#
# This information is in the call dataframe. Each call has a number, which we'll often use in place of its name

# %%
data.call_df.head(10)
# Out:
#   class number   class name            English_name        Scientific_name  \
# 0         none        Empty                   Empty           noise sample
# 1            1  Aegcau_call         Long-tailed Tit    Aegithalos caudatus
# 2            2  Alaarv_song        Eurasian Skylark        Alauda arvensis
# 3            3  Anttri_song              Tree Pipit       Anthus trivialis
# 4            4  Butbut_call          Common Buzzard            Buteo buteo
# 5            5  Carcan_call           Common Linnet      Linaria cannabina
# 6            6  Carcan_song           Common Linnet      Linaria cannabina
# 7            7  Carcar_call      European Goldfinch    Carduelis carduelis
# 8            8  Carcar_song      European Goldfinch    Carduelis carduelis
# 9            9  Cerbra_call  Short-toed Treecreeper  Certhia brachydactyla
#
#     type
# 0  noise
# 1   bird
# 2   bird
# 3   bird
# 4   bird
# 5   bird
# 6   bird
# 7   bird
# 8   bird
# 9   bird

# %% [markdown]
# ### How do we know the calls in a particular training audio clip?
#
# This is in the label dataframe. Each row is a particular training audio clip, and each column is a particular label. A 1 means the call is present, 0 means it is not

# %%
HTML(data.label_df.head(10).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>call_ids</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>45</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>61</th>
#       <th>62</th>
#       <th>63</th>
#       <th>64</th>
#       <th>65</th>
#       <th>66</th>
#       <th>67</th>
#       <th>68</th>
#       <th>69</th>
#       <th>70</th>
#       <th>71</th>
#       <th>72</th>
#       <th>73</th>
#       <th>74</th>
#       <th>75</th>
#       <th>76</th>
#       <th>77</th>
#       <th>78</th>
#       <th>79</th>
#       <th>80</th>
#       <th>81</th>
#       <th>82</th>
#       <th>83</th>
#       <th>84</th>
#       <th>85</th>
#       <th>86</th>
#       <th>87</th>
#     </tr>
#     <tr>
#       <th>filename</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>nips4b_birds_trainfile001.wav</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>nips4b_birds_trainfile002.wav</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>nips4b_birds_trainfile003.wav</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <t

# %% [markdown]
# ### Exercises
#
# 1. Which calls are not made by birds?
# 2. What is a filename for an audio clip containing an insect?

# %%
data.call_df.type.unique()
# Out:
# array(['noise', 'bird', 'insect', 'amphibian'], dtype=object)

# %% [markdown]
# ### What about the sound clips?

# %%
wavs = data.get_wav_dict()

# %% [markdown]
# #### Find all the clips with three calls

# %%
three_call_clipnames = data.label_df.index[data.label_df.sum(axis=1)==3]

# %% [markdown]
#  #### Plot the audio for one of these three-bird clips

# %%
plot(wavs[three_call_clipnames[1]])

# %% [markdown]
# #### That wasn't too helpful, maybe a spectrogram will be more illuminating

# %%
wav_utils.view_clip(three_call_clipnames[4])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile015.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>17</th>
#       <td>  Carrion Crow</td>
#       <td> bird</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>      Blue Tit</td>
#       <td> bird</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td> House Sparrow</td>
#       <td> bird</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Much better, how about some more clips

# %% [markdown]
# ###### Sounds (and looks) like there may be a stream in the background on this one

# %%
wav_utils.view_clip(three_call_clipnames[1])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile004.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>22</th>
#       <td>   European Robin</td>
#       <td> bird</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>          Dunnock</td>
#       <td> bird</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td> Common Blackbird</td>
#       <td> bird</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Is that a car in the background?

# %%
wav_utils.view_clip(data.label_df.index[32])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile033.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>29</th>
#       <td> Thekla Lark</td>
#       <td> bird</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###### Uhhhhh, anyone there?

# %%
wav_utils.view_clip(data.label_df.index[8])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile009.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
wav_utils.view_clip(data.label_df.index[31])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile032.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ###### That's an uncommonly interesting call, Firecrest

# %%
wav_utils.view_clip(data.label_df.index[34])
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:555px" >
#       <source src="files/data/NIPS4B_BIRD_CHALLENGE_TRAIN_TEST_WAV/train/nips4b_birds_trainfile035.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>English_name</th>
#       <th>type</th>
#     </tr>
#     <tr>
#       <th>call_ids</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>65</th>
#       <td> Common Firecrest</td>
#       <td> bird</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Exercises
#
# 1. Look at the clip you found that contains an insect
# 2. Find a clip you expect to be relatively easy to label correctly
# 3. Find a clip you expect to be challenging to label correctly
# 4. Look at the clips with 6 labels each
# 5. How many examples are there of each call?
#
# ### Bonus Exercises
#
# 1. Find some particularly noisy clips
# 2. Try to syllablize the wavs or spectrograms
# 3. Where does the syllablization break down?
# 4. Can we synthesize new labeled data by combining clips or exploiting invariances?
